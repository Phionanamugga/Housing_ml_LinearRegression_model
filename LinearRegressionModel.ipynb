# %% [markdown]
# Import libraries

# %%
import pandas
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error, r2_score

# %% [markdown]
# Understanding the problem

# %%
df = pandas.read_csv("https://raw.githubusercontent.com/Phionanamugga/teaching/refs/heads/main/datasets/housing.csv")

# %%
df.head()
# Out:
#    id     price  area  bedrooms  bathrooms  stories  stories.1  guestroom  \
# 0   0  13300000  7420         4          2        3          1          0
# 1   1  12250000  8960         4          4        4          1          0
# 2   2  12250000  9960         3          2        2          1          0
# 3   3  12215000  7500         4          2        2          1          0
# 4   4  11410000  7420         4          1        2          1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0               1.0
# 1               1.0
# 2               0.5
# 3               1.0
# 4               1.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                545 non-null    int64
#  1   price             545 non-null    int64
#  2   area              545 non-null    int64
#  3   bedrooms          545 non-null    int64
#  4   bathrooms         545 non-null    int64
#  5   stories           545 non-null    int64
#  6   stories.1         545 non-null    int64
#  7   guestroom         545 non-null    int64
#  8   basement          545 non-null    int64
#  9   hotwaterheating   545 non-null    int64
#  10  airconditioning   545 non-null    int64
#  11  parking           545 non-null    int64
#  12  prefarea          545 non-null    int64
#  13  furnishingstatus  545 non-null    float64
# dtypes: float64(1), int64(13)
# memory usage: 59.7 KB
# None

# %% [markdown]
# Split dataset

# %%
df_train, df_test = train_test_split(df)

print("df size:", df.size)
print("df_train size:", df_train.size)
print("df_test shape:", df_test.shape)
print("df size:", df.size)
print("df_train size:", df_train.size)
print("df_test size:", df_test.shape)
# Out:
# df size: 7630
# df_train size: 5712
# df_test shape: (137, 14)
# df size: 7630
# df_train size: 5712
# df_test size: (137, 14)

# %% [markdown]
# Data exploration

# %%
df_train.dtypes
# Out:
# id                    int64
# price                 int64
# area                  int64
# bedrooms              int64
# bathrooms             int64
# stories               int64
# stories.1             int64
# guestroom             int64
# basement              int64
# hotwaterheating       int64
# airconditioning       int64
# parking               int64
# prefarea              int64
# furnishingstatus    float64
# dtype: object

# %% [markdown]
# Plots bar graphs for the dataset

# %%
df_train.hist()
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'area'}>,
#         <Axes: title={'center': 'bedrooms'}>],
#        [<Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'stories'}>,
#         <Axes: title={'center': 'stories.1'}>,
#         <Axes: title={'center': 'guestroom'}>],
#        [<Axes: title={'center': 'basement'}>,
#         <Axes: title={'center': 'hotwaterheating'}>,
#         <Axes: title={'center': 'airconditioning'}>,
#         <Axes: title={'center': 'parking'}>],
#        [<Axes: title={'center': 'prefarea'}>,
#         <Axes: title={'center': 'furnishingstatus'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# Data processing

# %%
df = df.dropna()

# %% [markdown]
# Model training

# %%
x = df[['area']]
y = df[['price']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Intercep(b)t: {model.intercept_}")
print(f"Coefficient(w1): {model.coef_[0]}")
# Out:
# Intercep(b)t: [2512254.26395934]
# Coefficient(w1): [425.72984194]

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_log_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean_Squared_Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean_Squared_Error: 0.13338488811360213
# R-squared: 0.27287851871974644

# %%
plt.scatter(x_test, y_test, color='blue', label='Actual_Prices')
plt.plot(x_test, y_pred, color='red',linewidth=2, label='Predicted Prices')
plt.xlabel('Living Area(sqft)')
plt.ylabel('House Price')
plt.title('Linear Regression: House Price vs Living Area')
plt.legend()
plt.show()

# %%
# Convert x_test to a NumPy array (if it's not already)
x_test = np.array(x_test).reshape(-1, 1)  # Ensure it's a 2D array
y_test = np.array(y_test)  # Convert y_test to an array

# Create the scatter plot for actual house prices
plt.figure(figsize=(8,6))  # Adjust figure size for clarity
plt.scatter(x_test, y_test, color='blue', label='Actual Prices')

# Plot the regression line with a confidence interval
sns.regplot(x=x_test.flatten(), y=y_test, scatter=False, color='red', ci=95, line_kws={"linewidth": 2})

# Labels and title
plt.xlabel('Living Area (sqft)')
plt.ylabel('House Price')
plt.title('Linear Regression: House Price vs Living Area')

# Show legend
plt.legend()
plt.show()

# %% [markdown]
# Model evaluation

# %%
from sklearn.linear_model import LogisticRegression
import sklearn.metrics
import numpy as np

# Load or prepare your training data
# Example: x_train, x_test, y_train, y_test should be defined
# x_train, x_test = ... (your feature data)
# y_train, y_test = ... (your labels)

# Define and train the model
model = LogisticRegression()
model.fit(x_train, y_train)

# Make predictions
y_predicted = model.predict(x_test)

# Compute accuracy
accuracy = sklearn.metrics.accuracy_score(y_test, y_predicted)
print("Model Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       5 # Load or prepare your training data
#       6 # Example: x_train, x_test, y_train, y_test should be defined
#       7 # x_train, x_test = ... (your feature data)
#       8 # y_train, y_test = ... (your labels)
#       9
#      10 # Define and train the model
#      11 model = LogisticRegression()
# ---> 12 model.fit(x_train, y_train)
#      14 # Make predictions
#      15 y_predicted = model.predict(x_test)
#
# NameError: name 'x_train' is not defined
